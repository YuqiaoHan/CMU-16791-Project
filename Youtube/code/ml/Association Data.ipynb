# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('normalize_input424.csv')
df = df.drop(columns=['Unnamed: 0'])
df = df.drop(columns = ['video_id'])
df = df.drop(columns = ['daily_views'])
df = df.drop(columns = ['sub_date'])

# %%
df.head()
# Out:
#   channel frequency category_of_title_length tags_length_category  \
# 0              high                      low                  low
# 1              high                 moderate                  low
# 2              high                 moderate             moderate
# 3              high                      low                 high
# 4              high                      low             moderate
#
#    description_contains_facebook  description_contains_instagram  \
# 0                              1                               1
# 1                              0                               0
# 2                              1                               1
# 3                              1                               1
# 4                              1                               1
#
#    title_contains_num  title_contains_special  title_contains_brackets  \
# 0                   0                       0                        0
# ...

# %%
one_third = df.title_length_normal.quantile(1.0 / 3.0)
two_third = df.title_length_normal.quantile(2.0 / 3.0)
print('title length normal')
title_length_num = df.title_length_normal.tolist()
title_length_normal_classification = []
small = 0
mid =0
large = 0
for item in title_length_num:
    if item <= one_third:
        title_length_normal_classification.append("Small")
        small = small+ 1
    if item >  one_third and item <= two_third:
        title_length_normal_classification.append("Middle")
        mid = mid + 1
    if item > two_third:
        title_length_normal_classification.append("Large")
        large = large + 1
# 每日views分类
df["daily_view_classification"] = daily_views_classification
